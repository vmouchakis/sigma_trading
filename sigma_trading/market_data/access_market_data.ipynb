# %% [markdown]
# ## API Access to Market Data

# %% [markdown]
# ### Remote Data Access Using Pandas

# %% [markdown]
# #### Reading HTML Tables

# %%
import pandas as pd

sp_url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
sp = pd.read_html(sp_url, header=0)[0] # returns a list for each table
sp.info()
sp
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Symbol                 502 non-null    object
#  1   Security               502 non-null    object
#  2   SEC filings            502 non-null    object
#  3   GICS Sector            502 non-null    object
#  4   GICS Sub-Industry      502 non-null    object
#  5   Headquarters Location  502 non-null    object
#  6   Date first added       457 non-null    object
#  7   CIK                    502 non-null    int64
#  8   Founded                502 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 35.4+ KB
#     Symbol              Security SEC filings             GICS Sector  \
# 0      MMM                    3M     reports             Industrials
# 1      AOS           A. O. Smith     reports             Industrials
# ...

# %% [markdown]
# #### pandas-datareader for market Data

# %%
import pandas_datareader.data as web
from datetime import datetime

start = '2014'
# accepts strings
end = datetime(2017, 5, 24) # or datetime objects
yahoo= web.DataReader('FB', 'yahoo', start=start, end=end)
yahoo.info()
yahoo
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 253 entries, 2021-10-13 to 2022-10-13
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       253 non-null    float64
#  1   Low        253 non-null    float64
#  2   Open       253 non-null    float64
#  3   Close      253 non-null    float64
#  4   Volume     253 non-null    int64
#  5   Adj Close  253 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 13.8 KB
#                   High         Low        Open       Close    Volume  \
# Date
# 2021-10-13  327.000000  322.660004  326.970001  324.540009  14761500
# 2021-10-14  330.519989  327.100006  328.359985  328.529999  14302200
# 2021-10-15  329.070007  322.510010  328.679993  324.760010  21596400
# 2021-10-18  335.890015  327.500000  328.950012  335.339996  21585000
# 2021-10-19  342.459991  337.279999  339.649994  339.989990  18786300
# ...

# %% [markdown]
# ### Yahoo! Finance

# %%
import yfinance as yf

symbol = 'MSFT'
ticker = yf.Ticker(symbol)
data = ticker.history(period='5d',
                      interval='1m',
                      actions=True,
                      auto_adjust=True)
data.info()
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1684 entries, 2022-10-07 09:30:00-04:00 to 2022-10-13 11:39:52-04:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          1684 non-null   float64
#  1   High          1684 non-null   float64
#  2   Low           1684 non-null   float64
#  3   Close         1684 non-null   float64
#  4   Volume        1684 non-null   int64
#  5   Dividends     1684 non-null   int64
#  6   Stock Splits  1684 non-null   int64
# dtypes: float64(4), int64(3)
# memory usage: 105.2 KB
#                                  Open        High         Low       Close  \
# Datetime
# 2022-10-07 09:30:00-04:00  239.109497  239.109497  239.059998  239.059998
# 2022-10-07 09:31:00-04:00  238.854996  239.169998  238.139999  238.330002
# 2022-10-07 09:32:00-04:00  238.369995  238.410004  237.910004  237.940002
# ...

# %% [markdown]
# #### Download option chain and prices

# %%
ticker.options

options = ticker.option_chain("2022-10-14")
options.calls.info()
options
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   contractSymbol     52 non-null     object
#  1   lastTradeDate      52 non-null     datetime64[ns, UTC]
#  2   strike             52 non-null     float64
#  3   lastPrice          52 non-null     float64
#  4   bid                52 non-null     float64
#  5   ask                52 non-null     float64
#  6   change             52 non-null     float64
#  7   percentChange      52 non-null     float64
#  8   volume             52 non-null     int64
#  9   openInterest       52 non-null     int64
#  10  impliedVolatility  52 non-null     float64
#  11  inTheMoney         52 non-null     bool
#  12  contractSize       52 non-null     object
#  13  currency           52 non-null     object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(7), int64(2), object(3)
# ...

# %% [markdown]
# ### Quandl

# %%
# See documentation for this (requires api key)
# https://data.nasdaq.com/tools/api

import quandl

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Zipline + Quantopian

# %%
# More on Chapter 4
